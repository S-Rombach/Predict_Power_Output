# %% [markdown]
# # Plot a comparison of all evaluated models

# %% [markdown]
# ## Load All Models

# %%
import os
import json
import numpy as np
import pandas as pd
from src.config import SOLAR_PROD_HOURLY_MODELS_DIR as MODELS_DIR, MODEL_ALIASES

error_metrics = ["MAE", "MSE", "RMSE", "MedAE"]
high_exp_error_metrics = ["MAPE"]
score_metrics = ["R2", "ExplainedVar"]

target_keys = (
    [
        "timestamp",
        "model_purpose",
        "special_features",
        "model_class",
    ]
    + error_metrics
    + high_exp_error_metrics
    + score_metrics
)

subdirs = [
    d for d in os.listdir(MODELS_DIR) if os.path.isdir(d) and not d.startswith(".")
]


rows = []

for d in subdirs:
    result_path = os.path.join(MODELS_DIR, d, f"{d}.results.json")
    row = {}
    if os.path.exists(result_path):
        with open(result_path, "r") as f:
            data = json.load(f)

        for key in target_keys:
            val = data
            for part in key.split("__"):
                if isinstance(val, dict) and part in val:
                    val = val[part]
                else:
                    val = None
                    break
            row[key] = val
    else:
        continue
    row["dir"] = d
    rows.append(row)


df = pd.DataFrame(rows)

df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")


df = df.sort_values(by="R2", ascending=True)
display(df)

# %% [markdown]
# ## Print A Markdown Version Of The DataFrame

# %%
# df as markdown table
from tabulate import tabulate

print(tabulate(df.reset_index(), headers="keys", tablefmt="github", showindex=False))

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Styles

# %%
import matplotlib.pyplot as plt

cmap = plt.get_cmap("tab10")
colors = list(cmap.colors)

linestyles = ["-", "--", "-.", ":"]
markers = ["o", "s", "D", "^", "v", "<", ">", "x", "+", "*", "p", "h"]

def style_generator(markers=markers, linestyles=linestyles, colors=colors):
    for marker in markers:
        for linestyle in linestyles:
            for color in colors:
                yield {"color": color, "linestyle": linestyle, "marker": marker}

# %% [markdown]
# ### Function For Labels

# %%
# Fallback for row labels
def get_row_label(row):
    name = row.name.strftime("%m-%d %H:%M:%S") + " "

    if pd.notna(row.get("model_class")) and row["model_class"] != "":
        if row["model_class"] in MODEL_ALIASES:
            name += MODEL_ALIASES[str(row["model_class"])]
        else:
            name += str(row["model_class"])
        name += " "

    if pd.notna(row.get("special_features")) and row["special_features"] != "":
        name += str(row["special_features"])
    else:
        name += str(row.get("model_purpose", ""))


    name = f"{name}"
    return name

# %%
def plot_single_model(
    row, label, ax, metrics, annotate=False, **kwargs
):
    (line,) = ax.plot(
        metrics,
        row[metrics],
        label=label,
        **kwargs,
    )

    if annotate:
        for xx, col_name in enumerate(metrics):
            value = float(row[col_name])
            ax.annotate(
                f"{value:.2f}",
                xy=(xx, value),
                xytext=(5, 5),
                textcoords="offset points",
                ha="left",
                color=line.get_color(),
                fontsize=9,
            )

    return line

# %% [markdown]
# ### Plot Each Models Metrics

# %%
import matplotlib.transforms as mtransforms

df_show = df.copy()
df_baseline = df[df["model_purpose"].str.startswith("baseline")]

df_show = df_show[~df_show["model_purpose"].str.startswith("baseline")]

styles = style_generator()

# Create figure and axis
fig, axes = plt.subplots(
    figsize=(16, 5),
    ncols=3,
    gridspec_kw={
        "width_ratios": [
            len(error_metrics),
            len(high_exp_error_metrics),
            len(score_metrics),
        ]
    },
)
lines = {ax: [] for ax in axes}
alpha = 0.9
# Plot baseline(s)
baseline_style = style_generator(colors=["black"])
if not df_baseline.empty:
    for idx, row in df_baseline.iterrows():
        label = f"baseline: {get_row_label(row)}"
        style = next(baseline_style)

        for ax, metrics in zip(
            axes, [error_metrics, high_exp_error_metrics, score_metrics]
        ):
            line = plot_single_model(
                row,
                label if ax == axes[0] else None,  # only one label in legend
                ax,
                metrics,
                False,
                **(style | {"alpha": alpha}),
            )
            lines[ax].append((idx, line, row))

# Plot each row
for idx, row in df_show.iterrows():
    label = get_row_label(row)
    style = next(styles)
    for ax, metrics in zip(
        axes, [error_metrics, high_exp_error_metrics, score_metrics]
    ):
        line = plot_single_model(
            row,
            label if ax == axes[0] else None,  # only one label in legend
            ax,
            metrics,
            False,
            **(style | {"alpha": alpha}),
        )

        lines[ax].append((idx, line, row))

# Mark best value per column in the color of the best line
for ax, metrics, y_lim_max in zip(
    axes, [error_metrics, high_exp_error_metrics, score_metrics], [None, None, 1]
):
    for col in metrics:
        best_idx = df[col].idxmax() if col in score_metrics else df[col].idxmin()
        row = df.loc[best_idx]
        y = row[col]  # * (1.05 if col in score_metrics else 0.90)

        # constant pixel offset
        offset_px = 10 if col in score_metrics else -10

        x = list(metrics).index(col)

        # Calculate new y position with offset in display coordinates
        offset = mtransforms.ScaledTranslation(0, offset_px / 72.0, fig.dpi_scale_trans)
        trans = ax.transData + offset

        # Get the color of the corresponding line
        line_color = next(
            (l.get_color() for i, l, r in lines[ax] if i == best_idx), "black"
        )
        ax.plot(
            x,
            y,
            marker="v" if col in score_metrics else "^",
            color=line_color,
            markersize=8,
            alpha=alpha,
            transform=trans,
        )

# Axis and legend settings
for ax, metrics, title, y_label, y_scale, y_lim_max in zip(
    axes,
    [error_metrics, high_exp_error_metrics, score_metrics],
    ["Error Metrics", "Error Metrics", "Score Metrics"],
    [
        "MSE: $(W_ph)^2$, MAPE: None, else $W_ph$",
        "MSE: $(W_ph)^2$, MAPE: None, else $W_ph$",
        "Score",
    ],
    ["linear", "log", "linear"],
    [
        None,
        None,
        1,
    ],
):

    ax.set_xticks(range(len(metrics)))
    ax.set_xticklabels(metrics, rotation=0, ha="center")

    ax.grid(axis="y", linestyle="--", linewidth=0.5)
    ax.set_yscale(y_scale)
    if y_scale != "log":
        ax.set_ylim(ymin=0, ymax=y_lim_max)
    ax.set_title(title)
    ax.set_ylabel(y_label)
    # ax.legend()


fig.legend(bbox_to_anchor=(0.5, -0.01), loc="upper center", ncol=min(1, len(df_show)))
fig.suptitle("Comparison of models by selected metrics")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot A Chosen Models Metrics Vs The Aggregation Of All Others

# %%
target_model_timestamp = None  # e.g. "2023-10-01 12:00:00"
"""The timestamp of the target model to highlight. If None or empty, the latest model is used."""

df_show = df.copy()
df_baseline = df_show[df_show["model_purpose"].str.startswith("baseline")]

df_agg = (
    df[error_metrics + high_exp_error_metrics + score_metrics]
    .agg(["min", "max", "median"])
)

df_show[error_metrics] = df_show[error_metrics]
df_show = df_show[~df_show["model_purpose"].str.startswith("baseline")]


styles = style_generator()

# Create figure and axis
fig, axes = plt.subplots(
    figsize=(16, 5),
    ncols=3,
    gridspec_kw={"width_ratios": [len(error_metrics), len(high_exp_error_metrics), len(score_metrics)]},
)
lines = {ax: [] for ax in axes}
alpha = 0.9

# Plot range and median of metrics
for ax, metrics in zip(axes, [error_metrics, high_exp_error_metrics, score_metrics]):
    mean_vals = df_agg[metrics].loc["median"]
    (line,) = ax.plot(
        metrics,
        mean_vals,
        label="median" if ax == axes[0] else None,  # only one label in legend
        linestyle="--",
        alpha=0.7,
        color="gray",
    )
    ax.fill_between(
        metrics,
        df_agg[metrics].loc["min"],
        df_agg[metrics].loc["max"],
        alpha=0.3,
        label="min/max" if ax == axes[0] else None,  # only one label in legend
        color="lightgray",
    )

# Plot baseline(s)
baseline_style = style_generator(colors=["black"])
if not df_baseline.empty:
    for idx, row in df_baseline.iterrows():
        label = f"baseline: {get_row_label(row)}"
        style = next(baseline_style)

        for ax, metrics in zip(axes, [error_metrics, high_exp_error_metrics, score_metrics]):
            line = plot_single_model(
                row,
                label if ax == axes[0] else None,  # only one label in legend
                ax,
                metrics,
                False,
                **(style | {"alpha": alpha}),
            )
            lines[ax].append((idx, line, row))

if target_model_timestamp is None or target_model_timestamp == "":
    target_model_timestamp = df_show.index.max()
elif target_model_timestamp not in df_show.index:
    raise ValueError(f"timestamp '{target_model_timestamp}' not found in df.index")


# Plot single model
for idx, row in df_show.loc[df_show.index == target_model_timestamp, :].iterrows():
    label = get_row_label(row)
    style = next(styles)
    for ax, metrics in zip(axes, [error_metrics, high_exp_error_metrics, score_metrics]):
        line = plot_single_model(
            row,
            label if ax == axes[0] else None,  # only one label in legend
            ax,
            metrics,
            True,
            **(style | {"alpha": alpha}),
        )

# Axis and legend settings
for ax, metrics, title, y_label, y_scale, y_lim_max in zip(
    axes,
    [error_metrics, high_exp_error_metrics, score_metrics],
    ["Error Metrics", "Error Metrics", "Score Metrics"],
    [
        "MSE: $(W_ph)^2$, MAPE: None, else $W_ph$",
        "MSE: $(W_ph)^2$, MAPE: None, else $W_ph$",
        "Score",
    ],
    ["linear", "log", "linear"],
    [
        None,
        None,
        1,
    ],
):

    ax.set_xticks(range(len(metrics)))
    ax.set_xticklabels(metrics, rotation=0, ha="center")

    ax.grid(axis="y", linestyle="--", linewidth=0.5)
    ax.set_yscale(y_scale)
    if y_scale != "log":
        ax.set_ylim(ymin=0, ymax=y_lim_max)
    ax.set_title(title)
    ax.set_ylabel(y_label)

fig.legend(bbox_to_anchor=(0.5, -0.01), loc="upper center", ncol=min(1, len(df_show)))
fig.suptitle("Comparison of models by selected metrics")
plt.tight_layout()
plt.show()
